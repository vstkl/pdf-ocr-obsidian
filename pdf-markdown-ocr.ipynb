# %%
# Make sure you have the dependencies installed
# !pip install mistralai jupyter python-dotenv
# Out:
# Requirement already satisfied: mistralai in /home/diego/miniforge3/lib/python3.10/site-packages (1.5.1)
# Requirement already satisfied: jupyter in /home/diego/miniforge3/lib/python3.10/site-packages (1.1.1)
# Requirement already satisfied: python-dotenv in /home/diego/miniforge3/lib/python3.10/site-packages (1.0.1)
# Requirement already satisfied: eval-type-backport>=0.2.0 in /home/diego/miniforge3/lib/python3.10/site-packages (from mistralai) (0.2.2)
# Requirement already satisfied: httpx>=0.27.0 in /home/diego/miniforge3/lib/python3.10/site-packages (from mistralai) (0.27.2)
# Requirement already satisfied: jsonpath-python>=1.0.6 in /home/diego/miniforge3/lib/python3.10/site-packages (from mistralai) (1.0.6)
# Requirement already satisfied: pydantic>=2.9.0 in /home/diego/miniforge3/lib/python3.10/site-packages (from mistralai) (2.9.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/diego/miniforge3/lib/python3.10/site-packages (from mistralai) (2.9.0.post0)
# Requirement already satisfied: typing-inspect>=0.9.0 in /home/diego/miniforge3/lib/python3.10/site-packages (from mistralai) (0.9.0)
# Requirement already satisfied: notebook in /home/diego/miniforge3/lib/python3.10/site-packages (from jupyter) (7.3.2)
# Requirement already satisfied: jupyter-console in /home/diego/miniforge3/lib/python3.10/site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in /home/diego/miniforge3/lib/python3.10/site-packages (from jupyter) (7.16.6)
# Requirement already satisfied: ipykernel in /home/diego/miniforge3/lib/python3.10/site-packages (from jupyter) (6.29.5)
# Requirement already satisfied: ipywidgets in /home/diego/miniforge3/lib/python3.10/site-packages (from jupyter) (8.1.5)
# Requirement already satisfied: jupyterlab in /home/diego/miniforge3/lib/python3.10/site-packages (from jupyter) (4.3.5)
# Requirement already satisfied: anyio in /home/diego/miniforge3/lib/python3.10/site-packages (from httpx>=0.27.0->mistralai) (4.6.0)
# Requirement already satisfied: certifi in /home/diego/miniforge3/lib/python3.10/site-packages (from httpx>=0.27.0->mistralai) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /home/diego/miniforge3/lib/python3.10/site-packages (from httpx>=0.27.0->mistralai) (1.0.5)
# Requirement already satisfied: idna in /home/diego/miniforge3/lib/python3.10/site-packages (from httpx>=0.27.0->mistralai) (3.8)
# Requirement already satisfied: sniffio in /home/diego/miniforge3/lib/python3.10/site-packages (from httpx>=0.27.0->mistralai) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/diego/miniforge3/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.27.0->mistralai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/diego/miniforge3/lib/python3.10/site-packages (from pydantic>=2.9.0->mistralai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /home/diego/miniforge3/lib/python3.10/site-packages (from pydantic>=2.9.0->mistralai) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/diego/miniforge3/lib/python3.10/site-packages (from pydantic>=2.9.0->mistralai) (4.12.2)
# Requirement already satisfied: six>=1.5 in /home/diego/miniforge3/lib/python3.10/site-packages (from python-dateutil>=2.8.2->mistralai) (1.16.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/diego/miniforge3/lib/python3.10/site-packages (from typing-inspect>=0.9.0->mistralai) (1.0.0)
# Requirement already satisfied: comm>=0.1.1 in /home/diego/miniforge3/lib/python3.10/site-packages (from ipykernel->jupyter) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /home/diego/miniforge3/lib/python3.10/site-packages (from ipykernel->jupyter) (1.8.5)
# Requirement already satisfied: ipython>=7.23.1 in /home/diego/miniforge3/lib/python3.10/site-packages (from ipykernel->jupyter) (8.27.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/diego/miniforge3/lib/python3.10/site-packages (from ipykernel->jupyter) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/diego/miniforge3/lib/python3.10/site-packages (from ipykernel->jupyter) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/diego/miniforge3/lib/python3.10/site-packages (from ipykernel->jupyter) (0.1.7)
# Requirement already satisfied: nest-asyncio in /home/diego/miniforge3/lib/python3.10/site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: packaging in /home/diego/miniforge3/lib/python3.10/site-packages (from ipykernel->jupyter) (24.1)
# Requirement already satisfied: psutil in /home/diego/miniforge3/lib/python3.10/site-packages (from ipykernel->jupyter) (5.9.8)
# Requirement already satisfied: pyzmq>=24 in /home/diego/miniforge3/lib/python3.10/site-packages (from ipykernel->jupyter) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in /home/diego/miniforge3/lib/python3.10/site-packages (from ipykernel->jupyter) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in /home/diego/miniforge3/lib/python3.10/site-packages (from ipykernel->jupyter) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /home/diego/miniforge3/lib/python3.10/site-packages (from ipywidgets->jupyter) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /home/diego/miniforge3/lib/python3.10/site-packages (from ipywidgets->jupyter) (3.0.13)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /home/diego/miniforge3/lib/python3.10/site-packages (from jupyter-console->jupyter) (3.0.47)
# Requirement already satisfied: pygments in /home/diego/miniforge3/lib/python3.10/site-packages (from jupyter-console->jupyter) (2.18.0)
# Requirement already satisfied: async-lru>=1.0.0 in /home/diego/miniforge3/lib/python3.10/site-packages (from jupyterlab->jupyter) (2.0.4)
# Requirement already satisfied: jinja2>=3.0.3 in /home/diego/miniforge3/lib/python3.10/site-packages (from jupyterlab->jupyter) (3.1.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/diego/miniforge3/lib/python3.10/site-packages (from jupyterlab->jupyter) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/diego/miniforge3/lib/python3.10/site-packages (from jupyterlab->jupyter) (2.15.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /home/diego/miniforge3/lib/python3.10/site-packages (from jupyterlab->jupyter) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in /home/diego/miniforge3/lib/python3.10/site-packages (from jupyterlab->jupyter) (0.2.4)
# Requirement already satisfied: setuptools>=40.8.0 in /home/diego/miniforge3/lib/python3.10/site-packages (from jupyterlab->jupyter) (75.6.0)
# Requirement already satisfied: tomli>=1.2.2 in /home/diego/miniforge3/lib/python3.10/site-packages (from jupyterlab->jupyter) (2.2.1)
# Requirement already satisfied: beautifulsoup4 in /home/diego/miniforge3/lib/python3.10/site-packages (from nbconvert->jupyter) (4.13.3)
# Requirement already satisfied: bleach!=5.0.0 in /home/diego/miniforge3/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (6.2.0)
# Requirement already satisfied: defusedxml in /home/diego/miniforge3/lib/python3.10/site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/diego/miniforge3/lib/python3.10/site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /home/diego/miniforge3/lib/python3.10/site-packages (from nbconvert->jupyter) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/diego/miniforge3/lib/python3.10/site-packages (from nbconvert->jupyter) (3.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in /home/diego/miniforge3/lib/python3.10/site-packages (from nbconvert->jupyter) (0.10.2)
# Requirement already satisfied: nbformat>=5.7 in /home/diego/miniforge3/lib/python3.10/site-packages (from nbconvert->jupyter) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/diego/miniforge3/lib/python3.10/site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: webencodings in /home/diego/miniforge3/lib/python3.10/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /home/diego/miniforge3/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (1.4.0)
# Requirement already satisfied: decorator in /home/diego/miniforge3/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/diego/miniforge3/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.19.1)
# Requirement already satisfied: stack-data in /home/diego/miniforge3/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.6.3)
# Requirement already satisfied: exceptiongroup in /home/diego/miniforge3/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (1.2.2)
# Requirement already satisfied: pexpect>4.3 in /home/diego/miniforge3/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (4.9.0)
# Requirement already satisfied: platformdirs>=2.5 in /home/diego/miniforge3/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (4.2.2)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/diego/miniforge3/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /home/diego/miniforge3/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/diego/miniforge3/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /home/diego/miniforge3/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /home/diego/miniforge3/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.21.1)
# Requirement already satisfied: send2trash>=1.8.2 in /home/diego/miniforge3/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /home/diego/miniforge3/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /home/diego/miniforge3/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.0)
# Requirement already satisfied: babel>=2.10 in /home/diego/miniforge3/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /home/diego/miniforge3/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.10.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/diego/miniforge3/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (4.23.0)
# Requirement already satisfied: requests>=2.31 in /home/diego/miniforge3/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.32.3)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/diego/miniforge3/lib/python3.10/site-packages (from nbformat>=5.7->nbconvert->jupyter) (2.21.1)
# Requirement already satisfied: wcwidth in /home/diego/miniforge3/lib/python3.10/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in /home/diego/miniforge3/lib/python3.10/site-packages (from beautifulsoup4->nbconvert->jupyter) (2.6)
# Requirement already satisfied: argon2-cffi-bindings in /home/diego/miniforge3/lib/python3.10/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (21.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/diego/miniforge3/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /home/diego/miniforge3/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/diego/miniforge3/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/diego/miniforge3/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/diego/miniforge3/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.21.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/diego/miniforge3/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.2.1)
# Requirement already satisfied: pyyaml>=5.3 in /home/diego/miniforge3/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (6.0.2)
# Requirement already satisfied: rfc3339-validator in /home/diego/miniforge3/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/diego/miniforge3/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.1)
# Requirement already satisfied: ptyprocess>=0.5 in /home/diego/miniforge3/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter) (0.7.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/diego/miniforge3/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/diego/miniforge3/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.2.2)
# Requirement already satisfied: executing>=1.2.0 in /home/diego/miniforge3/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/diego/miniforge3/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.4.1)
# Requirement already satisfied: pure-eval in /home/diego/miniforge3/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.2.3)
# Requirement already satisfied: fqdn in /home/diego/miniforge3/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in /home/diego/miniforge3/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/diego/miniforge3/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0.0)
# Requirement already satisfied: uri-template in /home/diego/miniforge3/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /home/diego/miniforge3/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in /home/diego/miniforge3/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.17.1)
# Requirement already satisfied: pycparser in /home/diego/miniforge3/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in /home/diego/miniforge3/lib/python3.10/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /home/diego/miniforge3/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.9.0.20241206)

# %%
import json
import base64
import shutil
from pathlib import Path
from mistralai import Mistral, DocumentURLChunk
from mistralai.models import OCRResponse

# %%
# The only requirement for this script is to have a Mistral API Key.
# You can get a free API Key at: https://console.mistral.ai/api-keys
# You can put the api key in the .env file (see the README.md for more information)
# or you can put it directly in the script below.

import os
from dotenv import load_dotenv

load_dotenv()

# Option 1: Load API key from .env file
api_key = os.getenv("MISTRAL_API_KEY")

# Option 2: Hardcoded API key (fallback)
if not api_key:
    api_key = "your-hardcoded-api-key-here"

print(f"Loaded API Key: {api_key[:4]}...")
client = Mistral(api_key=api_key)
# Out:
# Loaded API Key: w94a...

# %%
# Path configuration
INPUT_DIR = Path("pdfs_to_process")   # Folder where the user places the PDFs to be processed
DONE_DIR = Path("pdfs-done")            # Folder where processed PDFs will be moved
OUTPUT_ROOT_DIR = Path("ocr_output")    # Root folder for conversion results

# Ensure directories exist
INPUT_DIR.mkdir(exist_ok=True)
DONE_DIR.mkdir(exist_ok=True)
OUTPUT_ROOT_DIR.mkdir(exist_ok=True)

# %%
def replace_images_in_markdown(markdown_str: str, images_dict: dict) -> str:
    """
    This converts base64 encoded images directly in the markdown...
    And replaces them with links to external images, so the markdown is more readable and organized.
    """
    for img_name, base64_str in images_dict.items():
        markdown_str = markdown_str.replace(f"![{img_name}]({img_name})", f"![{img_name}]({base64_str})")
    return markdown_str

def get_combined_markdown(ocr_response: OCRResponse) -> str:
    """
    Part of the response from the Mistral API, which is an OCRResponse object...
    And returns a single string with the combined markdown of all the pages of the PDF.
    """
    markdowns: list[str] = []
    for page in ocr_response.pages:
        image_data = {}
        for img in page.images:
            image_data[img.id] = img.image_base64
        markdowns.append(replace_images_in_markdown(page.markdown, image_data))

    return "\n\n".join(markdowns)

# %%
def process_pdf(pdf_path: Path):
    # Process all PDFs in INPUT_DIR
    # - Important to be careful with the number of PDFs, as the Mistral API has a usage limit
    #   and it could cause errors by exceeding the limit.

    # PDF base name
    pdf_base = pdf_path.stem
    print(f"Processing {pdf_path.name} ...")
    
    # Output folders
    output_dir = OUTPUT_ROOT_DIR / pdf_base
    output_dir.mkdir(exist_ok=True)
    images_dir = output_dir / "images"
    images_dir.mkdir(exist_ok=True)
    
    # PDF -> OCR
    with open(pdf_path, "rb") as f:
        pdf_bytes = f.read()
        
    uploaded_file = client.files.upload(
        file={
            "file_name": pdf_path.name,
            "content": pdf_bytes,
        },
        purpose="ocr"
    )
    
    signed_url = client.files.get_signed_url(file_id=uploaded_file.id, expiry=1)
    
    ocr_response = client.ocr.process(
        document=DocumentURLChunk(document_url=signed_url.url),
        model="mistral-ocr-latest",
        include_image_base64=True
    )
    
    # Save OCR in JSON 
    # (in case something fails it could be reused, but it is not used in the rest of the code)
    ocr_json_path = output_dir / "ocr_response.json"
    with open(ocr_json_path, "w", encoding="utf-8") as json_file:
        json.dump(ocr_response.dict(), json_file, indent=4, ensure_ascii=False)
    print(f"OCR response saved in {ocr_json_path}")
    
    # OCR -> Markdown prepared for Obsidian
    # - That is, from base64 encoded images, it converts them to links to 
    #   external images and generates the images as such, in a subfolder.
    
    global_counter = 1
    updated_markdown_pages = []
    
    for page in ocr_response.pages:
        updated_markdown = page.markdown
        for image_obj in page.images:
            
            # base64 to image
            base64_str = image_obj.image_base64
            if base64_str.startswith("data:"):
                base64_str = base64_str.split(",", 1)[1]
            image_bytes = base64.b64decode(base64_str)
            
            # image extensions
            ext = Path(image_obj.id).suffix if Path(image_obj.id).suffix else ".png"
            new_image_name = f"{pdf_base}_img_{global_counter}{ext}"
            global_counter += 1
            
            # save in subfolder
            image_output_path = images_dir / new_image_name
            with open(image_output_path, "wb") as f:
                f.write(image_bytes)
            
            # Update markdown with wikilink: ![[nombre_imagen]]
            updated_markdown = updated_markdown.replace(
                f"![{image_obj.id}]({image_obj.id})",
                f"![[{new_image_name}]]"
            )
        updated_markdown_pages.append(updated_markdown)
    
    final_markdown = "\n\n".join(updated_markdown_pages)
    output_markdown_path = output_dir / "output.md"
    with open(output_markdown_path, "w", encoding="utf-8") as md_file:
        md_file.write(final_markdown)
    print(f"Markdown generated in {output_markdown_path}")

# %%
# Process all PDFs in INPUT_DIR
# - Important to be careful with the number of PDFs, as the Mistral API has a usage limit
#   and it could cause errors by exceeding the limit.

pdf_files = list(INPUT_DIR.glob("*.pdf"))      # Get all PDFs in pdfs_to_process. So make sure to place the PDFs there.
if not pdf_files:
    print("No PDFs to process.")
    exit()
    
for pdf_file in pdf_files:
    try:
        process_pdf(pdf_file)
        shutil.move(str(pdf_file), DONE_DIR / pdf_file.name)
        print(f"{pdf_file.name} moved to {DONE_DIR}")
    except Exception as e:
        print(f"Error processing {pdf_file.name}: {e}")
# Out:
# Processing 24I623 val.pdf ...
# OCR response saved in ocr_output/24I623 val/ocr_response.json
# Markdown generated in ocr_output/24I623 val/output.md
# 24I623 val.pdf moved to pdfs-done
